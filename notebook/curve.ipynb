# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  #### BSA-PM: Position Mutation
#  #### Non-linear parameter decrease from 2 to 0.
#  #### a = a_std - (a_std - a_fin) * (1/(e-1) * (e^(FEs/Max_FEs) - 1))^2
#  #### a_std = 2, a_fin = 0

# %%
# Function definition
def curve_function(FEs, Max_FEs):
    return 2 - 2 * (1 / (np.e - 1) * (np.exp(FEs / Max_FEs) - 1)) ** 2

# Parameters
Max_FEs = 500
FEs_values = np.linspace(0, Max_FEs, 1000)

# Generate curve values
curve_values = curve_function(FEs_values, Max_FEs)

# Plotting the curve
plt.plot(FEs_values, curve_values, label='Corrected Curve Function')
plt.title('Corrected Curve Function')
plt.xlabel('FEs (Function Evaluations)')
plt.ylabel('a')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Mutation Step
# #### p = C_max - rand * (-(sin(pi/(2*FEs)) + C_min))
# #### C_max = 3, C_min = 1

# %%
# Function definition for the new curve
def new_curve_function(FEs, C_max, C_min):
    rand = np.random.random(len(FEs))
    return C_max - rand * (-(np.sin(np.pi / (2 * FEs)) + C_min))

# Parameters
C_max = 3
C_min = 1

# Generate new curve values
new_curve_values = new_curve_function(FEs_values, C_max, C_min)

# Plotting the new curve
plt.plot(FEs_values, new_curve_values, label='New Curve Function')
plt.title('New Curve Function')
plt.xlabel('FEs (Function Evaluations)')
plt.ylabel('p')
plt.legend()
plt.grid(True)

# Marking dots for FEs = 0, 1, 2, 3, ..., 500
dots_FEs = np.arange(0, 501, 50)
dots_values = new_curve_function(dots_FEs, C_max, C_min)
plt.scatter(dots_FEs, dots_values, color='red', label='Dots at FEs')

plt.legend()
plt.show()

# %%
# Corrected function definition for the new curve with rand in the range [0, 1)
def corrected_new_curve_function(FEs, C_max, C_min):
    rand = np.random.rand(len(FEs))  # Use np.random.rand for random numbers in [0, 1)
    return C_max - rand * (-np.sin(np.pi / (2 * FEs)) + C_min)

# Generate corrected new curve values
corrected_new_curve_values = corrected_new_curve_function(FEs_values, C_max, C_min)

# Plotting the corrected new curve
plt.plot(FEs_values, corrected_new_curve_values, label='Corrected New Curve Function')
plt.title('Corrected New Curve Function')
plt.xlabel('FEs (Function Evaluations)')
plt.ylabel('p')
plt.legend()
plt.grid(True)

# Marking dots for FEs = 0, 1, 2, 3, ..., 500
dots_FEs = np.arange(0, 501, 10)
dots_values = corrected_new_curve_function(dots_FEs, C_max, C_min)
plt.scatter(dots_FEs, dots_values, color='red', label='Dots at FEs')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def calculate_a(FEs, Max_FEs):
    return 1 - 1/5 * np.arctanh(-(FEs / Max_FEs) + 1)

# Generate FEs values
FEs_values = np.arange(30, 300001, 30)

# Calculate corresponding 'a' values
a_values = calculate_a(FEs_values, 300000)

# Plot the function
plt.plot(FEs_values, a_values)
plt.title('Function: a = 1 - 1/5 * atanh(-(FEs/Max_FEs) + 1)')
plt.xlabel('FEs')
plt.ylabel('a')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def calculate_a(FEs, Max_FEs):
    return 1 - np.arctanh(FEs /(2*Max_FEs))

# Generate FEs values
FEs_values = np.arange(30, 300001, 30)

# Calculate corresponding 'a' values
a_values = calculate_a(FEs_values, 300000)

# Plot the function
plt.plot(FEs_values, a_values)
plt.title('Function: a = 1 - atanh(FEs/(2*Max_FEs))')
plt.xlabel('FEs')
plt.ylabel('a')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def calculate_a(FEs, Max_FEs):
    return 1 - 1/5 * np.arctanh(FEs /(2*Max_FEs))

# Generate FEs values
FEs_values = np.arange(30, 300001, 30)

# Calculate corresponding 'a' values
a_values = calculate_a(FEs_values, 300000)

# Plot the function
plt.plot(FEs_values, a_values)
plt.title('Function: a = 1 - 1/5 * atanh(FEs/(2*Max_FEs))')
plt.xlabel('FEs')
plt.ylabel('a')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def calculate_a(FEs, Max_FEs):
    return np.arctanh(-(FEs / Max_FEs) + 1)

# Generate FEs values
FEs_values = np.arange(30, 300001, 30)

# Calculate corresponding 'a' values
a_values = calculate_a(FEs_values, 300000)

# Plot the function with dots
plt.plot(FEs_values, a_values, label='Function: $a = \\tanh(-(FEs/Max_FEs) + 1)$')
plt.scatter(FEs_values, a_values, color='red', label='Dots at FEs')
plt.title('Function: $a = \\tanh(-(FEs/Max_FEs) + 1)$ with Dots')
plt.xlabel('FEs')
plt.ylabel('a')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def calculate_b(FEs, Max_FEs):
    return 1 - FEs / Max_FEs

# Generate FEs values
FEs_values_b = np.arange(30, 300001, 30)

# Calculate corresponding 'b' values
b_values = calculate_b(FEs_values_b, 300000)

# Plot the function
plt.plot(FEs_values_b, b_values, label='Function: $b = 1 - \\frac{FEs}{Max\_FEs}$')
plt.title('Function: $b = 1 - \\frac{FEs}{Max\_FEs}$')
plt.xlabel('FEs')
plt.ylabel('b')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate x values for tanh curve
x_values_tanh = np.linspace(-10, 10, 100)

# Calculate corresponding tanh values
tanh_values_curve = np.tanh(x_values_tanh)

# Plot the tanh curve
plt.plot(x_values_tanh, tanh_values_curve, label='$\\tanh(x)$')
plt.title('Tanh Curve: $\\tanh(x)$')
plt.xlabel('x')
plt.ylabel('tanh')
plt.grid(True)
plt.show()

# %%
import math

result = math.tanh(10)
print(result)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate x values for tanh curve
x_values_tanh = np.linspace(-10, 10, 100)

# Calculate corresponding tanh values
tanh_values_curve = np.tanh(x_values_tanh)

# Calculate inverted tanh values for x < 0
inverted_tanh_values = -np.tanh(x_values_tanh[x_values_tanh < 0])

# Combine the original and inverted tanh values
combined_tanh_values = np.concatenate([tanh_values_curve[x_values_tanh >= 0], inverted_tanh_values])

# Plot the original and inverted tanh curves
plt.plot(x_values_tanh, tanh_values_curve, label='$\\tanh(x)$')
plt.plot(x_values_tanh[x_values_tanh < 0], inverted_tanh_values, label='$tanh(-x)$', linestyle='dashed')
plt.title('Inverted Tanh Curve for $x < 0$')
plt.xlabel('x')
plt.ylabel('tanh')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
u = 4       # Mean
sigma = 2   # Standard deviation

# Generate x values for the curve
x = np.linspace(u - 4*sigma, u + 4*sigma, 1000)

# Compute the PDF values for each x
pdf_values = norm.pdf(x, loc=u, scale=sigma)

# Plot the PDF curve
plt.figure()
plt.plot(x, pdf_values, linewidth=2)
plt.title('Normal Distribution PDF')
plt.xlabel('X')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Mutation Step
# #### p = C_max - rand * (-(sin(pi/(2*FEs)) + C_min))
# #### C_max = 3, C_min = 1

# %%
import numpy as np
import matplotlib.pyplot as plt
# Function definition for the new curve
def new_curve_function(FEs, C_max, C_min):
    rand = np.random.random(len(FEs))
    return C_max - rand * (-(np.sin(np.pi / (2 * FEs)) + C_min))

Max_FEs = 300000
FEs_values = np.linspace(0, Max_FEs, 1000)

# Parameters
C_max = 3
C_min = 1

# Generate new curve values
new_curve_values = new_curve_function(FEs_values, C_max, C_min)

# Plotting the new curve
plt.plot(FEs_values, new_curve_values, label='New Curve Function')
plt.title('New Curve Function')
plt.xlabel('FEs (Function Evaluations)')
plt.ylabel('p')
plt.legend()
plt.grid(True)

# Marking dots for FEs = 0, 1, 2, 3, ..., 500
dots_FEs = np.arange(0, 501, 50)
dots_values = new_curve_function(dots_FEs, C_max, C_min)
plt.scatter(dots_FEs, dots_values, color='red', label='Dots at FEs')

plt.legend()
plt.show()

# %% [markdown]
# #### C_max - rand * (-sin(pi / (2 * FEs)) + C_min)

# %%
# Corrected function definition for the new curve with rand in the range [0, 1)
def corrected_new_curve_function(FEs, C_max, C_min):
    rand = np.random.rand(len(FEs))  # Use np.random.rand for random numbers in [0, 1)
    return C_max - rand * (-np.sin(np.pi / (2 * FEs)) + C_min)

# Generate corrected new curve values
corrected_new_curve_values = corrected_new_curve_function(FEs_values, C_max, C_min)

# Plotting the corrected new curve
plt.plot(FEs_values, corrected_new_curve_values, label='Corrected New Curve Function')
plt.title('Corrected New Curve Function')
plt.xlabel('FEs (Function Evaluations)')
plt.ylabel('p')
plt.legend()
plt.grid(True)

# Marking dots for FEs = 0, 1, 2, 3, ..., 500
dots_FEs = np.arange(0, 501, 10)
dots_values = corrected_new_curve_function(dots_FEs, C_max, C_min)
plt.scatter(dots_FEs, dots_values, color='red', label='Dots at FEs')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the concave function and chord
def concave_function(x):
    return 1/2 * x ** 4 

def chord(x):
    return 1 - x

# Generate x values
x_values = np.linspace(0, 1, 100)

# Calculate corresponding y values for the function and chord
y_values_function = concave_function(x_values)
y_values_chord = chord(x_values)

# Plot the concave function and chord
plt.plot(x_values, y_values_function, label='Concave Function: $f(x) = -x^2 + 2x$')
plt.plot(x_values, y_values_chord, '--', label='Chord: $y = 1 - x$')
plt.scatter([0, 1], [1, 0], color='red', marker='o', label='Points (0,1) and (1,0)')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Concave Function Passing Through (0,1) and (1,0)')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the logistic function
def logistic_function(x):
    return 1 / (1 + np.exp(-3*x))

# Generate x values
x_values = np.linspace(-5, 5, 100)

# Calculate corresponding y values
y_values = logistic_function(x_values)

# Plot the logistic function
plt.plot(x_values, y_values, label='$f(x) = \\frac{1}{1 + e^{-3x}}$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Logistic Function')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def custom_function(x):
    return -1.61 * np.log(x + 0.54) + 1.45

# Generate x values
x_values = np.linspace(0.1, 5, 100)  # Avoid x <= -0.54 due to the logarithmic term

# Calculate corresponding y values
y_values = custom_function(x_values)

# Plot the function
plt.plot(x_values, y_values, label='$f(x) = -1.61 \\ln(x + 0.54) + 1.45$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Custom Function')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified sigmoid-like function
def sigmoid_like_function(x):
    return np.tanh(4 * (x - 0.5))

# Generate x values
x_values = np.linspace(0, 1, 100)

# Calculate corresponding y values for the sigmoid-like function
y_values = sigmoid_like_function(x_values)

# Plot the sigmoid-like function
plt.plot(x_values, y_values, label='$f(x) = \\tanh(4(x-0.5))$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Sigmoid-Like Reflection Function')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified sigmoid-like function
def sigmoid_like_function(x):
    return 1 / (1 + np.exp(-8 * (x - 0.5)))

# Generate x values
x_values = np.linspace(0, 1, 100)

# Calculate corresponding y values for the sigmoid-like function
y_values = sigmoid_like_function(x_values)

# Plot the sigmoid-like function
plt.plot(x_values, y_values, label='$f(x) = \\frac{1}{1 + e^{-8(x-0.5)}}$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the scaled sigmoid-like function
def scaled_sigmoid_like_function(x, a=1):
    return 1 / (1 + np.exp(-a * (x - 0.5)))

# Generate x values
x_values = np.linspace(0, 100, 10)

# Calculate corresponding y values for the scaled sigmoid-like function
y_values = scaled_sigmoid_like_function(x_values, a=0.1)  # Adjust the scaling factor

# Plot the scaled sigmoid-like function
plt.plot(x_values, y_values, label='$f(x) = \\frac{1}{1 + e^{-a(x-0.5)}}$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Scaled Sigmoid-Like Reflection Function')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
a = 1
b = 0.5

# Generate x values
x_values = np.linspace(0, 1, 100)

# Calculate corresponding y values for the reflected function
reflected_function = 1 / (1 + np.exp(-a * (x_values - b)))

# Plot the reflected function
plt.plot(x_values, reflected_function, linewidth=2)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Reflected Sigmoid Function')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
a = 0.02
b = 50  # Adjust the starting point

# Generate x values
x_values = np.linspace(0, 300, 100)

# Calculate corresponding y values for the sigmoid-like function
sigmoid_function = 1 / (1 + np.exp(-a * (x_values - b)))

# Plot the sigmoid-like function
plt.plot(x_values, sigmoid_function, linewidth=2)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Modified Sigmoid Function')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# Define parameters
a = 0.02
b = 50  # Adjust the starting point

# Generate x values
x_values = np.linspace(0, 200, 100)

Max_FEs = 300000
FEs = np.linspace(0, 300000, 100)

# Calculate corresponding y values for the modified sigmoid-like function
sigmoid_function = 1 / (1 + np.exp(-a * (x_values - b)))
# y = (np.sin(x_values/100) + FEs/Max_FEs) / 2


########## test
# y = 1 - (1 - FEs/Max_FEs)**(np.tanh(x_values))
t = random.random()
print(t)
y = 1/(1 + np.exp(-x_values)) * np.sqrt(FEs/Max_FEs) ##########
print(y)


# Scale and shift the sigmoid function to meet the requirements
scaled_sigmoid_function = sigmoid_function * 1.3  # Scale to 0.8 for saturation
shifted_sigmoid_function = scaled_sigmoid_function - 0.3  # Shift to start from (0, 0)

# Plot the modified sigmoid-like function
plt.plot(x_values, shifted_sigmoid_function, linewidth=2)
plt.plot(x_values, y, linewidth=2)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Modified Sigmoid Function')
plt.grid(True)
plt.show()
# Out:
# 0.5505062342171027
# [0.         0.08873498 0.13967684 0.17367248 0.20094539 0.22472407
#  0.24618164 0.26590782 0.28426759 0.30151134 0.31782086 0.33333333
#  0.34815531 0.36237154 0.37605072 0.38924947 0.40201513 0.41438771
#  0.42640143 0.43808583 0.44946657 0.46056619 0.47140452 0.4819992
#  0.49236596 0.50251891 0.51247074 0.52223297 0.53181602 0.54122943
#  0.55048188 0.55958137 0.56853524 0.57735027 0.58603272 0.59458839
#  0.60302269 0.61134064 0.61954692 0.62764591 0.63564173 0.6435382
#  0.65133895 0.65904737 0.66666667 0.67419986 0.68164981 0.68901921
#  0.69631062 0.70352647 0.71066905 0.71774056 0.72474308 0.73167857
#  0.73854895 0.74535599 0.75210143 0.75878691 0.765414   0.77198419
#  0.77849894 0.78495963 0.79136757 0.79772404 0.80403025 0.81028739
#  0.81649658 0.82265891 0.82877541 0.83484711 0.84087497 0.84685992
#  0.85280287 0.85870469 0.86456622 0.87038828 0.87617165 0.8819171
#  0.88762536 0.89329715 0.89893315 0.90453403 0.91010045 0.91563303
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
a = 0.02
b = 50  # Adjust the starting point

# Generate x values
x_values = np.linspace(0, 200, 100)

# Calculate corresponding y values for the modified sigmoid-like function
sigmoid_function = 1 / (1 + np.exp(-a * (x_values - b)))

# Scale and shift the sigmoid function to meet the requirements
scaled_sigmoid_function = sigmoid_function * 1.1  # Scale to 0.8 for saturation
shifted_sigmoid_function = scaled_sigmoid_function - 0.1  # Shift to start from (0, 0)

# Plot the modified sigmoid-like function
plt.plot(x_values, shifted_sigmoid_function, linewidth=2)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Modified Sigmoid Function')
plt.grid(True)
plt.show()
